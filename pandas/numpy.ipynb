# %%
import numpy as np
import matplotlib.pylab as plt
from numpy import random

m_list_1 = [[1,2,3],[4,5,4],[7,8,9]]
np_m_arr = np.array(m_list_1)

np.arange(1,10)
np.linspace(0,5,5)
np.zeros((3,3))

np_m_arr.size
np_m_arr.dtype
# Out:
# dtype('int32')
